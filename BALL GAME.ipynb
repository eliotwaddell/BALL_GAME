# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('BALL_2020.csv')
df = df.drop(df.columns[0], axis=1)
df.sort_values(by='FT%', axis=0, ascending = False).loc[df['G'] > 40].head(20)
# Out:
#                Player    Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 557        Tony Snell     SF   28  DET  59  57  27.8  2.9   6.5  0.445  ...
# 186      Jared Dudley     PF   34  LAL  45   1   8.1  0.5   1.3  0.400  ...
# 516   Duncan Robinson     SG   25  MIA  73  68  29.7  4.4   9.4  0.470  ...
# 614    Brad Wanamaker     PG   30  BOS  71   1  19.3  2.3   5.1  0.448  ...
# 248     Marko Guduric     SG   24  MEM  44   0  11.0  1.4   3.6  0.395  ...
# 68       Devin Booker     SG   23  PHO  70  70  35.9  9.0  18.3  0.489  ...
# 418   Khris Middleton     SF   28  MIL  62  59  29.9  7.6  15.3  0.497  ...
# 488        Chris Paul     PG   34  OKC  70  70  31.5  6.2  12.7  0.489  ...
# 60   Bojan Bogdanović     SF   30  UTA  63  63  33.1  6.6  14.8  0.447  ...
# 126        Gary Clark  SF-PF   25  TOT  42   5  13.5  1.3   3.2  0.406  ...
# 96         Alec Burks     SF   28  GSW  48  18  29.0  5.1  12.5  0.406  ...
# ...
